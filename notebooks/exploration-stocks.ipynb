# %%
import pandas as pd
import plotly.express as px
from extraetf import stocks

# %%
results1j = stocks.search(sort_by="calculated_return_price_1y", ordering="desc", limit=100, filters={"ms_marketcap": {"gt": 10000000000}})

# %%
df_results = pd.DataFrame(results1j)

# %%
df_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  100 non-null    object
#  1   isin                  100 non-null    object
#  2   country               99 non-null     object
#  3   sector                100 non-null    object
#  4   industry              100 non-null    object
#  5   earnings_per_share    95 non-null     float64
#  6   dividend_yield        67 non-null     float64
#  7   market_cap            100 non-null    int64
#  8   price_to_eps          96 non-null     float64
#  9   price_to_book         100 non-null    float64
#  10  ps_ratio              100 non-null    float64
#  11  price_to_cash_flow    100 non-null    float64
#  12  return_on_investment  98 non-null     float64
#  13  week_1                100 non-null    float64
#  14  month_1               100 non-null    float64
# ...

# %%
px.scatter(df_results, x="current_year", y="dividend_yield", hover_data=["name", "isin"])
